# %% [markdown]
# # Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#modeling
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Daten laden und vorverarbeiten

# %%
train=pd.read_csv('/Users/hoahuynh/Downloads/MA_1.Semester/3-ML/Praktikum/input/train.csv') 
test=pd.read_csv('/Users/hoahuynh/Downloads/MA_1.Semester/3-ML/Praktikum/input/test.csv')

# %%
train["file_path"] = train["Id"].apply(lambda x: "/Users/hoahuynh/Downloads/MA_1.Semester/3-ML/Praktikum/input/train/" + x + ".jpg")
train = train.drop(['Subject Focus', 'Eyes', 'Face', 'Near', 'Action', 'Accessory', 'Group', 'Collage', 'Human', 'Occlusion', 'Info', 'Blur'],axis=1)

test["file_path"] = test["Id"].apply(lambda x: "/Users/hoahuynh/Downloads/MA_1.Semester/3-ML/Praktikum/input/test/" + x + ".jpg")
test = test.drop(['Subject Focus', 'Eyes', 'Face', 'Near', 'Action', 'Accessory', 'Group', 'Collage', 'Human', 'Occlusion', 'Info', 'Blur'],axis=1)

# %%
#train

# %%
image_size = 128
def preprocess(image_url):
    image_string = tf.io.read_file(image_url)
    image = tf.image.decode_jpeg(image_string, channels=3)
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.image.central_crop(image, 1.0)
    image = tf.image.resize(image, (image_size, image_size))
    return image
x_train=[]
for i in train['file_path']:
    x1=preprocess(i)
    x_train.append(x1)
    
    
X=np.array(x_train)
y=train['Pawpularity']
# Out:
# Metal device set to: Apple M1 Pro
# 2023-02-28 12:56:37.384292: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-02-28 12:56:37.384405: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=7)

# %% [markdown]
# # ResNet152

# %%
def create_model(input_shape, top='flatten'):
    if top not in ('flatten', 'avg', 'max'):
        raise ValueError('unexpected top layer type: %s' % top)

    # connects base model with new "head"
    BottleneckLayer = {
        'flatten': keras.layers.Flatten(),
        'avg': keras.layers.GlobalAveragePooling2D(),
        'max': keras.layers.GlobalMaxPool2D()
    }[top]

    base = tf.keras.applications.resnet.ResNet152(input_shape=input_shape, include_top=False, weights='imagenet')

    x = BottleneckLayer(base.output)
    x = keras.layers.Dropout(0.5)(x)
    x = keras.layers.Dense(1, activation='relu')(x)
    model = tf.keras.Model(inputs=base.inputs, outputs=x)
    return model


early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_rmse',patience=10, verbose=1,mode='min',restore_best_weights=True
    )
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_rmse",
    factor=0.2,
    patience=3, 
    min_lr=1e-7,
    verbose=1,
    mode='min'
    )
callbacks = [early_stop,reduce_lr]


input_shape=(128,128,3)
model=create_model(input_shape)

# %%
#model.summary()

# %% [markdown]
# # Training mit Verlustfunktion "mse"

# %%
model.compile(loss='mse', optimizer='Adam', metrics=[tf.keras.metrics.RootMeanSquaredError(name="rmse"), "mae"])

# %%
#history = model.fit(x_train,y_train,epochs=5,batch_size=128,validation_data=(x_test,y_test),callbacks=callbacks)

#you can use this to provide your model with different variations of the same images. 
# It doesn't actually make and save a bunch of new images, just defines how new images can be created. 
# These transformations will randomly be applied to the training images as they get used in training.
data_augmentation = ImageDataGenerator(
    rotation_range = 15, 
    zoom_range = 0.15,
    width_shift_range = 0.2, 
    height_shift_range = 0.2, 
    shear_range = 0.1,
    horizontal_flip = True, 
    fill_mode = "nearest")

history = model.fit(
    data_augmentation.flow(x_train,y_train,batch_size=32),
    validation_data = (x_test,y_test),
    steps_per_epoch = len(x_train) // 32,
    epochs = 20
)
# Out:
# Epoch 1/20
# 2023-02-28 13:00:03.364578: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-02-28 13:00:10.849468: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 247/247 [==============================] - ETA: 0s - loss: 494.6186 - rmse: 22.2400 - mae: 16.7066
# 2023-02-28 13:02:20.702423: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 247/247 [==============================] - 154s 524ms/step - loss: 494.6186 - rmse: 22.2400 - mae: 16.7066 - val_loss: 39199100.0000 - val_rmse: 6260.9185 - val_mae: 6111.9097
# Epoch 2/20
# 247/247 [==============================] - 107s 432ms/step - loss: 444.5023 - rmse: 21.0832 - mae: 15.7592 - val_loss: 1497.4055 - val_rmse: 38.6963 - val_mae: 32.5449
# Epoch 3/20
# 247/247 [==============================] - 104s 423ms/step - loss: 432.1321 - rmse: 20.7878 - mae: 15.6466 - val_loss: 436.2681 - val_rmse: 20.8870 - val_mae: 15.5271
# Epoch 4/20
# 247/247 [==============================] - 104s 422ms/step - loss: 430.3770 - rmse: 20.7455 - mae: 15.5544 - val_loss: 564.1239 - val_rmse: 23.7513 - val_mae: 20.3435
# Epoch 5/20
# 247/247 [==============================] - 104s 420ms/step - loss: 428.7589 - rmse: 20.7065 - mae: 15.4941 - val_loss: 437.4680 - val_rmse: 20.9157 - val_mae: 16.0875
# Epoch 6/20
# 247/247 [==============================] - 104s 421ms/step - loss: 427.0966 - rmse: 20.6663 - mae: 15.4678 - val_loss: 446.4165 - val_rmse: 21.1286 - val_mae: 16.6479
# Epoch 7/20
# 247/247 [==============================] - 104s 420ms/step - loss: 425.8339 - rmse: 20.6357 - mae: 15.4613 - val_loss: 454.0388 - val_rmse: 21.3082 - val_mae: 16.8340
# Epoch 8/20
# 247/247 [==============================] - 104s 419ms/step - loss: 428.8095 - rmse: 20.7077 - mae: 15.5457 - val_loss: 678.2455 - val_rmse: 26.0431 - val_mae: 22.7615
# Epoch 9/20
# 247/247 [==============================] - 104s 422ms/step - loss: 426.9992 - rmse: 20.6640 - mae: 15.4944 - val_loss: 468.3849 - val_rmse: 21.6422 - val_mae: 15.1110
# Epoch 10/20
# 247/247 [==============================] - 104s 421ms/step - loss: 429.0671 - rmse: 20.7139 - mae: 15.5301 - val_loss: 490.4586 - val_rmse: 22.1463 - val_mae: 17.0953
# Epoch 11/20
# 247/247 [==============================] - 104s 420ms/step - loss: 427.0984 - rmse: 20.6664 - mae: 15.4763 - val_loss: 789.2004 - val_rmse: 28.0927 - val_mae: 20.6207
# Epoch 12/20
# 247/247 [==============================] - 104s 421ms/step - loss: 427.3842 - rmse: 20.6733 - mae: 15.4477 - val_loss: 460.6877 - val_rmse: 21.4636 - val_mae: 15.0917
# Epoch 13/20
# 247/247 [==============================] - 104s 420ms/step - loss: 425.9406 - rmse: 20.6383 - mae: 15.4568 - val_loss: 444.1500 - val_rmse: 21.0749 - val_mae: 16.4810
# Epoch 14/20
# 247/247 [==============================] - 103s 418ms/step - loss: 423.7513 - rmse: 20.5852 - mae: 15.4371 - val_loss: 452.3541 - val_rmse: 21.2686 - val_mae: 15.1210
# Epoch 15/20
# 247/247 [==============================] - 105s 424ms/step - loss: 425.6556 - rmse: 20.6314 - mae: 15.4409 - val_loss: 440.1859 - val_rmse: 20.9806 - val_mae: 15.1649
# Epoch 16/20
# 247/247 [==============================] - 104s 419ms/step - loss: 423.0790 - rmse: 20.5689 - mae: 15.4246 - val_loss: 456.1893 - val_rmse: 21.3586 - val_mae: 15.1209
# Epoch 17/20
# 247/247 [==============================] - 104s 419ms/step - loss: 421.9630 - rmse: 20.5417 - mae: 15.4243 - val_loss: 433.6805 - val_rmse: 20.8250 - val_mae: 15.9230
# Epoch 18/20
# 247/247 [==============================] - 104s 420ms/step - loss: 427.3895 - rmse: 20.6734 - mae: 15.5064 - val_loss: 440.3328 - val_rmse: 20.9841 - val_mae: 16.2952
# Epoch 19/20
# 247/247 [==============================] - 104s 420ms/step - loss: 426.6494 - rmse: 20.6555 - mae: 15.4947 - val_loss: 468.8145 - val_rmse: 21.6521 - val_mae: 17.5225
# Epoch 20/20
# 247/247 [==============================] - 104s 421ms/step - loss: 427.2682 - rmse: 20.6705 - mae: 15.4952 - val_loss: 720.0922 - val_rmse: 26.8345 - val_mae: 19.2458

# %% [markdown]
# # Model evaluieren

# %%
plt.figure()
plt.title("resNet152 Model mit Verlustfunktion MSE")

plt.plot(history.history["rmse"], label="train_rmse")
plt.plot(history.history["val_rmse"], label="val_rmse")
plt.plot(history.history["mae"], label="train_mae")
plt.plot(history.history["val_mae"], label="val_mae")

plt.legend(loc='upper right', bbox_to_anchor=(1, 0.5))
plt.savefig('10_resNet152_Model_mit_Verlustfunktion_MSE.png')
plt.show()

# %% [markdown]
# # Training mit Verlustfunktion "mae"

# %%
#compile the model
model.compile(
    loss = 'mae', 
    optimizer ='Adam', 
    metrics = [tf.keras.metrics.RootMeanSquaredError(name="rmse"), "mae"])

# %%
#you can use this to provide your model with different variations of the same images. 
# It doesn't actually make and save a bunch of new images, just defines how new images can be created. 
# These transformations will randomly be applied to the training images as they get used in training.
data_augmentation = ImageDataGenerator(
    rotation_range = 15, 
    zoom_range = 0.15,
    width_shift_range = 0.2, 
    height_shift_range = 0.2, 
    shear_range = 0.1,
    horizontal_flip = True, 
    fill_mode = "nearest")

history2 = model.fit(
    data_augmentation.flow(x_train,y_train,batch_size=32),
    validation_data = (x_test,y_test),
    steps_per_epoch = len(x_train) // 32,
    epochs = 20
)
# Out:
# Epoch 1/20
# 2023-02-28 13:35:44.520390: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 247/247 [==============================] - ETA: 0s - loss: 15.0241 - rmse: 21.1902 - mae: 15.0241
# 2023-02-28 13:38:12.260010: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 247/247 [==============================] - 178s 561ms/step - loss: 15.0241 - rmse: 21.1902 - mae: 15.0241 - val_loss: 18.1075 - val_rmse: 25.7615 - val_mae: 18.1075
# Epoch 2/20
# 247/247 [==============================] - 107s 431ms/step - loss: 14.9052 - rmse: 21.1548 - mae: 14.9052 - val_loss: 19.3879 - val_rmse: 26.9581 - val_mae: 19.3879
# Epoch 3/20
# 247/247 [==============================] - 104s 420ms/step - loss: 15.0367 - rmse: 21.2275 - mae: 15.0367 - val_loss: 15.0997 - val_rmse: 21.2806 - val_mae: 15.0997
# Epoch 4/20
# 247/247 [==============================] - 107s 431ms/step - loss: 14.9125 - rmse: 21.1290 - mae: 14.9125 - val_loss: 15.6639 - val_rmse: 22.9041 - val_mae: 15.6639
# Epoch 5/20
# 247/247 [==============================] - 104s 421ms/step - loss: 14.8859 - rmse: 21.1734 - mae: 14.8859 - val_loss: 15.1073 - val_rmse: 21.6099 - val_mae: 15.1073
# Epoch 6/20
# 247/247 [==============================] - 103s 417ms/step - loss: 14.8313 - rmse: 21.0924 - mae: 14.8313 - val_loss: 15.1624 - val_rmse: 21.1012 - val_mae: 15.1624
# Epoch 7/20
# 247/247 [==============================] - 103s 417ms/step - loss: 14.9111 - rmse: 21.1540 - mae: 14.9111 - val_loss: 15.5703 - val_rmse: 20.8714 - val_mae: 15.5703
# Epoch 8/20
# 247/247 [==============================] - 103s 417ms/step - loss: 15.0000 - rmse: 21.2737 - mae: 15.0000 - val_loss: 87.0634 - val_rmse: 130.5721 - val_mae: 87.0634
# Epoch 9/20
# 247/247 [==============================] - 103s 417ms/step - loss: 14.9177 - rmse: 21.2020 - mae: 14.9177 - val_loss: 15.1543 - val_rmse: 21.8043 - val_mae: 15.1543
# Epoch 10/20
# 247/247 [==============================] - 104s 420ms/step - loss: 14.8699 - rmse: 21.1227 - mae: 14.8699 - val_loss: 20.2369 - val_rmse: 27.7551 - val_mae: 20.2369
# Epoch 11/20
# 247/247 [==============================] - 103s 417ms/step - loss: 14.8421 - rmse: 21.1862 - mae: 14.8421 - val_loss: 15.4425 - val_rmse: 20.9135 - val_mae: 15.4425
# Epoch 12/20
# 247/247 [==============================] - 104s 419ms/step - loss: 14.8962 - rmse: 21.1553 - mae: 14.8962 - val_loss: 15.2114 - val_rmse: 22.0149 - val_mae: 15.2114
# Epoch 13/20
# 247/247 [==============================] - 104s 419ms/step - loss: 14.8887 - rmse: 21.1671 - mae: 14.8887 - val_loss: 15.2818 - val_rmse: 20.9877 - val_mae: 15.2818
# Epoch 14/20
# 247/247 [==============================] - 104s 421ms/step - loss: 14.8332 - rmse: 21.1331 - mae: 14.8332 - val_loss: 15.3103 - val_rmse: 22.2732 - val_mae: 15.3103
# Epoch 15/20
# 247/247 [==============================] - 105s 426ms/step - loss: 14.8794 - rmse: 21.1831 - mae: 14.8794 - val_loss: 15.2402 - val_rmse: 22.0854 - val_mae: 15.2402
# Epoch 16/20
# 247/247 [==============================] - 103s 416ms/step - loss: 14.8513 - rmse: 21.1740 - mae: 14.8513 - val_loss: 15.1021 - val_rmse: 21.5199 - val_mae: 15.1021
# Epoch 17/20
# 247/247 [==============================] - 103s 417ms/step - loss: 14.8686 - rmse: 21.1530 - mae: 14.8686 - val_loss: 15.1411 - val_rmse: 21.3322 - val_mae: 15.1411
# Epoch 18/20
# 247/247 [==============================] - 103s 417ms/step - loss: 14.8792 - rmse: 21.1637 - mae: 14.8792 - val_loss: 16.3250 - val_rmse: 21.0267 - val_mae: 16.3250
# Epoch 19/20
# 247/247 [==============================] - 103s 417ms/step - loss: 14.8678 - rmse: 21.1327 - mae: 14.8678 - val_loss: 15.3722 - val_rmse: 22.3979 - val_mae: 15.3722
# Epoch 20/20
# 247/247 [==============================] - 106s 427ms/step - loss: 14.8371 - rmse: 21.1411 - mae: 14.8371 - val_loss: 15.3381 - val_rmse: 20.9518 - val_mae: 15.3381

# %% [markdown]
# # Model erneut evaluieren

# %%
plt.figure()
plt.title("resNet152 Model mit Verlustfunktion MAE")

plt.plot(history2.history["rmse"], label="train_rmse")
plt.plot(history2.history["val_rmse"], label="val_rmse")
plt.plot(history2.history["mae"], label="train_mae")
plt.plot(history2.history["val_mae"], label="val_mae")

plt.legend(loc='upper right', bbox_to_anchor=(1, 0.5))
plt.savefig('11_resNet152_Model_mit_Verlustfunktion_MAE.png')
plt.show()

# %% [markdown]
# # Vergleich

# %%
plt.figure()
plt.title("Trainingperformance")

plt.subplot(221)
plt.title('train_rmse')
plt.plot(history.history["rmse"], label="train_rmse_1")
plt.plot(history2.history["rmse"], label="train_rmse_2")
plt.legend()

plt.subplot(222)
plt.title('val_rmse')
plt.plot(history.history["val_rmse"], label="val_rmse_1")
plt.plot(history2.history["val_rmse"], label="val_rmse_2")
plt.legend()

plt.subplot(223)
plt.title('train_mae')
plt.plot(history.history["mae"], label="train_mae_1")
plt.plot(history2.history["mae"], label="train_mae_2")
plt.legend()

plt.subplot(224)
plt.title('val_mae')
plt.plot(history.history["val_mae"], label="val_mae_1")
plt.plot(history2.history["val_mae"], label="val_mae_2")
plt.legend()

plt.savefig('12_resNet152_Model_Gesamt.png')
plt.show()
# Out:
# /var/folders/7l/64k945l9567573m_x6qrs0_80000gn/T/ipykernel_18846/3221631248.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(221)
